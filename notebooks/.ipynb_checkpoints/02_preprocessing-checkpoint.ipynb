# %%
# Importe
import json
import os
import re
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import pprint
import json
import spacy

# %%
# Dateipfade
metadata_path = "../data/raw/metadata/metadata.json"
lyrics_path = "../data/raw/lyrics/lyrics.json"

# Pfad zum Ordner
folder_path = "../data/processed"
os.makedirs(folder_path, exist_ok=True)

# %%
# Rohdaten laden
with open(metadata_path, "r", encoding="utf-8") as f:
    metadata = json.load(f)

with open(lyrics_path, "r", encoding="utf-8") as f:
    lyrics = json.load(f)

# %% [markdown]
# PREPROCESSING

# %%
# Eigene Rap-Adlibs
custom_adlibs = [
    "ey", "yo", "ah", "hm", "uh", "haha", "he", "hey", "ho", "huh", "haa", "hoho", 
    "woo", "yea", "yuh", "ay", "oh", "ayyaye", "ya", "ey", "ough", "skrr", "bam", 
    "pow", "bang", "brr", "choo", "bla", "bluh", "woa", "ye", "ya", "ayyy", "ayyyyo", 
    "yo", "ye", "ha", "äh", "ehm"
]
# Stopwords inkl. Adlibs
stop_words = set(stopwords.words('german') + stopwords.words('english') + custom_adlibs)

# %%
# Bereinigung der Lyrics 
def clean_lyrics(text):
    text = re.sub(r'\s+', ' ', text)      # Mehrfache Leerzeichen -> 1 Leerzeichen
    text = re.sub(r'[^\w\s]', '', text)   # Sonderzeichen entfernen
    text = text.lower()                    # Alles in Kleinbuchstaben
    return text.strip()

# %%
# Entfernt alle Tokens, die mit einem Adlib beginnen
def remove_adlib_tokens(tokens):
    cleaned_tokens = []
    for t in tokens:
        if not any(t.lower().startswith(adlib) for adlib in custom_adlips):
            cleaned_tokens.append(t)
    return cleaned_tokens

# %%
# Stopwords + Adlips entfernen
def remove_stopwords(tokens):
    return [t for t in tokens if t not in stop_words]

# %%
# Tokenisierung
def tokenize_lyrics(text):
    return word_tokenize(text)

# %%
# Lemmatisierung
nlp = spacy.load("de_core_news_sm")

def lemmatize_tokens(tokens):
    doc = nlp(" ".join(tokens))
    return [token.lemma_ for token in doc if token.text.strip()]

# %%
# DataFrame erzeugen + Preprocessing
def create_song_dataframe(metadata, lyrics):
    rows = []
    for artist_songs in metadata["artists"].values():
        for song in artist_songs:
            sid = song["song_id"]
            raw_lyrics = lyrics.get(sid, {}).get("lyrics", "")
            cleaned = clean_lyrics(raw_lyrics)
            
            tokens = tokenize_lyrics(cleaned)
            tokens_no_adlibs = remove_adlib_tokens(tokens)
            tokens_no_stop = remove_stopwords(tokens)
            lemmas = lemmatize_tokens(tokens_no_stop)
            
            rows.append({
                "song_id": sid,
                "artist_name": song["artist_name"],
                 "song_title": song["song_title"],
                "album_name": song["album_name"],
                "year": song["release_date"],
                "song_url": song["song_url"],
                "album_url": song["album_url"],
                "lyrics_clean": cleaned,
                "lyrics_tokens": tokens_no_stop,
                "lyrics_lemmas": lemmas
            })
    
    df = pd.DataFrame(rows)
    return df

# %%
# DataFrame erstellen
df_songs = create_song_dataframe(metadata, lyrics)

# %%
# Vorschau
preview = df_songs.head(3).to_dict(orient="records")

# Ausgabe
print(json.dumps(preview, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "song_id": "63d930f4-022f-4212-bf8f-ff3e6b343b13",
#     "artist_name": "DJ Reckless",
#     "song_title": "Banger Spieler Atzen Dealer",
#     "album_name": "Unknown",
#     "year": "Unknown",
#     "song_url": "https://genius.com/Dj-reckless-banger-spieler-atzen-dealer-lyrics",
#     "album_url": null,
#     "lyrics_clean": "banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila reckless mein name bass ohne gnade pushe heiße ware ich mache das bare yeah stell mir bеsser keine fragеn scheine sind lila digga schreibe schwarze zahlen mache schnelles cash mit dem mega mega bass die nutten lieben es und neider schieben hass yo yo du weißt genau dass der scheiß bangt shababs gehen bis der club abbrennt corner an der avenue tempelhofer damm wo die jungs im viertel hängen und die schwarzen benzers fahren bin kein gangster nein nur ein atze im kiez der das widerspiegelt was man auf der straße so sieht chromfelgen glänzen bei nacht geschäfte werden gemacht treffpunkt albuintanke business läuft gut bruder danke banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila in dieser stadt geht es um gewalt und cash fiftyfifty bist du fake oder echt bares geld in der unterwelt dicke potte in der tasche ist alles was zählt 7eleven würfelspiel an der mauer sig sauer neun millimeter power mercedesstern glänzt im licht goldkette hat gewicht triff mich im bezirk tempelhof am chillen banger machen action hauen dealer pushen pillen crystal meth kokain crocodile heroin flakka flakka hauptsache geld verdienen alles was du brauchst gar kein problem wenn du was willst dann musst dus dir nehmen jeden tag geht der hustle wieder los kleine kapseln aber risiko groß banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila banger spieler atzen dealer anzug von fila und das bare ist lila",
#     "lyrics_tokens": [
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "reckless",
#       "name",
#       "bass",
#       "gnade",
#       "pushe",
#       "heiße",
#       "ware",
#       "mache",
#       "bare",
#       "yeah",
#       "stell",
#       "bеsser",
#       "fragеn",
#       "scheine",
#       "lila",
#       "digga",
#       "schreibe",
#       "schwarze",
#       "zahlen",
#       "mache",
#       "schnelles",
#       "cash",
#       "mega",
#       "mega",
#       "bass",
#       "nutten",
#       "lieben",
#       "neider",
#       "schieben",
#       "hass",
#       "weißt",
#       "genau",
#       "scheiß",
#       "bangt",
#       "shababs",
#       "gehen",
#       "club",
#       "abbrennt",
#       "corner",
#       "avenue",
#       "tempelhofer",
#       "damm",
#       "jungs",
#       "viertel",
#       "hängen",
#       "schwarzen",
#       "benzers",
#       "fahren",
#       "gangster",
#       "nein",
#       "atze",
#       "kiez",
#       "widerspiegelt",
#       "straße",
#       "sieht",
#       "chromfelgen",
#       "glänzen",
#       "nacht",
#       "geschäfte",
#       "gemacht",
#       "treffpunkt",
#       "albuintanke",
#       "business",
#       "läuft",
#       "gut",
#       "bruder",
#       "danke",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "stadt",
#       "geht",
#       "gewalt",
#       "cash",
#       "fiftyfifty",
#       "fake",
#       "echt",
#       "bares",
#       "geld",
#       "unterwelt",
#       "dicke",
#       "potte",
#       "tasche",
#       "zählt",
#       "7eleven",
#       "würfelspiel",
#       "mauer",
#       "sig",
#       "sauer",
#       "neun",
#       "millimeter",
#       "power",
#       "mercedesstern",
#       "glänzt",
#       "licht",
#       "goldkette",
#       "gewicht",
#       "triff",
#       "bezirk",
#       "tempelhof",
#       "chillen",
#       "banger",
#       "action",
#       "hauen",
#       "dealer",
#       "pushen",
#       "pillen",
#       "crystal",
#       "meth",
#       "kokain",
#       "crocodile",
#       "heroin",
#       "flakka",
#       "flakka",
#       "hauptsache",
#       "geld",
#       "verdienen",
#       "brauchst",
#       "gar",
#       "problem",
#       "willst",
#       "musst",
#       "dus",
#       "nehmen",
#       "tag",
#       "geht",
#       "hustle",
#       "los",
#       "kleine",
#       "kapseln",
#       "risiko",
#       "groß",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila",
#       "banger",
#       "spieler",
#       "atzen",
#       "dealer",
#       "anzug",
#       "fila",
#       "bare",
#       "lila"
#     ],
#     "lyrics_lemmas": [
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Reckless",
#       "Name",
#       "Bass",
#       "gnade",
#       "Pushe",
#       "heiß",
#       "Ware",
#       "machen",
#       "bar",
#       "Yeah",
#       "stell",
#       "Bеsser",
#       "Fragеn",
#       "Scheine",
#       "Lila",
#       "Digga",
#       "schreiben",
#       "schwarz",
#       "Zahl",
#       "machen",
#       "schnelles",
#       "cash",
#       "mega",
#       "Mega",
#       "Bass",
#       "nutten",
#       "lieben",
#       "neider",
#       "schieben",
#       "Hass",
#       "Weißt",
#       "genau",
#       "scheiß",
#       "bangen",
#       "shababs",
#       "gehen",
#       "Club",
#       "abbrennen",
#       "Corner",
#       "Avenue",
#       "Tempelhofer",
#       "damm",
#       "jungs",
#       "Viertel",
#       "hängen",
#       "schwarz",
#       "Benzer",
#       "fahren",
#       "Gangster",
#       "nein",
#       "atz",
#       "Kiez",
#       "widerspiegeln",
#       "Straße",
#       "sehen",
#       "Chromfelg",
#       "glänzen",
#       "Nacht",
#       "Geschäft",
#       "machen",
#       "treffpunken",
#       "albuintanke",
#       "business",
#       "laufen",
#       "gut",
#       "Bruder",
#       "danker",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Stadt",
#       "gehen",
#       "Gewalt",
#       "cash",
#       "fiftyfifty",
#       "fake",
#       "echt",
#       "bar",
#       "Geld",
#       "unterwelt",
#       "dick",
#       "pott",
#       "Tasche",
#       "zählen",
#       "7eleven",
#       "Würfelspiel",
#       "Mauer",
#       "sig",
#       "sauer",
#       "neun",
#       "Millimeter",
#       "Power",
#       "Mercedesstern",
#       "glänzt",
#       "Licht",
#       "Goldkette",
#       "Gewicht",
#       "Triff",
#       "Bezirk",
#       "Tempelhof",
#       "Chillen",
#       "Banger",
#       "Action",
#       "hauen",
#       "deal",
#       "push",
#       "Pill",
#       "Crystal",
#       "Meth",
#       "Kokain",
#       "Crocodile",
#       "heroin",
#       "Flakka",
#       "Flakka",
#       "hauptsach",
#       "Geld",
#       "verdienen",
#       "brauchst",
#       "gar",
#       "Problem",
#       "willst",
#       "Musst",
#       "dus",
#       "nehmen",
#       "Tag",
#       "gehen",
#       "Hustle",
#       "los",
#       "klein",
#       "Kapsel",
#       "Risiko",
#       "groß",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila",
#       "Banger",
#       "Spieler",
#       "atzen",
#       "deal",
#       "Anzug",
#       "Fila",
#       "bar",
#       "Lila"
#     ]
#   },
#   {
#     "song_id": "1ff69cff-e495-4d76-9470-af5d73839bee",
#     "artist_name": "DJ Reckless",
#     "song_title": "Wir Raven Weiter",
#     "album_name": "Peppen Pappen Teile",
#     "year": "August 6, 2021",
#     "song_url": "https://genius.com/Dj-reckless-and-mc-bomber-wir-raven-weiter-lyrics",
#     "album_url": "https://genius.com/albums/Dj-reckless-and-mc-bomber/Peppen-pappen-teile",
#     "lyrics_clean": "wir raven weiter die leute sitzen traurig in ihrn scheiß verkackten buden zu hause weil die clubs zu haben wir raven weiter aber ist uns relativ latte denn wir raven weiter reckless und abfahrt wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir ravеn weiter weitеr wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter bomber das einmanndiscogeschwader mit 15 jahren war ich oympiakader dopingtest immer positiv willst du oben spieln musst du drogen ziehn ganz viel meine nasenscheidewand ist aus platin die kokaline zeckt wie wasabi sieben tage wach im laserlicht und pappen im rachen sind raverpflicht mit reckless auf der piste geht es immer nach vorn wir machen keine kompromisse technokinder des zorns aha berlin weiß ich bin ein mann vom fach ich bleibe wach solang die lila welle klatscht der stampft durchs land ein ewiger tanz wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter mc bomber ist auf acid dj reckless ist auf bass bass seit jahren am feiern wir haben den absprung verpasst oh je wir raven weiter ohne limit ohne pause nonstop drei tage wach mit substanzen in der brause acid techno und electro ist der sound auf dem wir surfen 808 und 303 die synapsen sind am twerken meine droge ist der bass so bin ich programmiert wir raven weiter bis jeder den verstand verliert wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter ouah reckless alter ick bin so drauf so drauf war ick noch nie alter wir raven weiter lass ma noch zur afterhour zu susanne in schöneberg dikka ouah wir raven weiter weiter weiter wir raven weiter weiter weiter wir raven weiter weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter wir raven weiter weiter weiter weiter weiter wir raven weiter weiter weiter weiter weiter wir raven weiter",
#     "lyrics_tokens": [
#       "raven",
#       "leute",
#       "sitzen",
#       "traurig",
#       "ihrn",
#       "scheiß",
#       "verkackten",
#       "buden",
#       "hause",
#       "clubs",
#       "raven",
#       "relativ",
#       "latte",
#       "raven",
#       "reckless",
#       "abfahrt",
#       "raven",
#       "raven",
#       "raven",
#       "ravеn",
#       "weitеr",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "bomber",
#       "einmanndiscogeschwader",
#       "15",
#       "jahren",
#       "oympiakader",
#       "dopingtest",
#       "immer",
#       "positiv",
#       "willst",
#       "oben",
#       "spieln",
#       "musst",
#       "drogen",
#       "ziehn",
#       "ganz",
#       "nasenscheidewand",
#       "platin",
#       "kokaline",
#       "zeckt",
#       "wasabi",
#       "sieben",
#       "tage",
#       "wach",
#       "laserlicht",
#       "pappen",
#       "rachen",
#       "raverpflicht",
#       "reckless",
#       "piste",
#       "geht",
#       "immer",
#       "vorn",
#       "kompromisse",
#       "technokinder",
#       "zorns",
#       "aha",
#       "berlin",
#       "weiß",
#       "mann",
#       "fach",
#       "bleibe",
#       "wach",
#       "solang",
#       "lila",
#       "welle",
#       "klatscht",
#       "stampft",
#       "durchs",
#       "land",
#       "ewiger",
#       "tanz",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "mc",
#       "bomber",
#       "acid",
#       "dj",
#       "reckless",
#       "bass",
#       "bass",
#       "seit",
#       "jahren",
#       "feiern",
#       "absprung",
#       "verpasst",
#       "je",
#       "raven",
#       "limit",
#       "pause",
#       "nonstop",
#       "drei",
#       "tage",
#       "wach",
#       "substanzen",
#       "brause",
#       "acid",
#       "techno",
#       "electro",
#       "sound",
#       "surfen",
#       "808",
#       "303",
#       "synapsen",
#       "twerken",
#       "droge",
#       "bass",
#       "programmiert",
#       "raven",
#       "verstand",
#       "verliert",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "ouah",
#       "reckless",
#       "alter",
#       "ick",
#       "drauf",
#       "drauf",
#       "ick",
#       "nie",
#       "alter",
#       "raven",
#       "lass",
#       "afterhour",
#       "susanne",
#       "schöneberg",
#       "dikka",
#       "ouah",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven",
#       "raven"
#     ],
#     "lyrics_lemmas": [
#       "rav",
#       "Leute",
#       "sitzen",
#       "traurig",
#       "Ihrn",
#       "scheiß",
#       "verkackt",
#       "bud",
#       "Haus",
#       "Club",
#       "Rave",
#       "relativ",
#       "Latte",
#       "raven",
#       "Reckless",
#       "abfahrt",
#       "rav",
#       "rav",
#       "rav",
#       "Ravеn",
#       "Weitеr",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "Bomber",
#       "einmanndiscogeschwader",
#       "15",
#       "Jahr",
#       "oympiakad",
#       "dopingtester",
#       "immer",
#       "positiv",
#       "willst",
#       "oben",
#       "spieln",
#       "Musst",
#       "Droge",
#       "ziehn",
#       "ganz",
#       "Nasenscheidewand",
#       "Platin",
#       "Kokaline",
#       "zecken",
#       "Wasabi",
#       "sieben",
#       "Tag",
#       "Wach",
#       "Laserlicht",
#       "pappen",
#       "rach",
#       "Raverpflicht",
#       "Reckless",
#       "Piste",
#       "gehen",
#       "immer",
#       "vorn",
#       "kompromissen",
#       "Technokinder",
#       "Zorns",
#       "Aha",
#       "Berlin",
#       "wissen",
#       "Mann",
#       "Fach",
#       "bleiben",
#       "Wach",
#       "Solang",
#       "Lila",
#       "Welle",
#       "Klatscht",
#       "stampfen",
#       "durch",
#       "Land",
#       "ewig",
#       "Tanz",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "Mc",
#       "Bomber",
#       "Acid",
#       "dj",
#       "reckless",
#       "Bass",
#       "Bass",
#       "seit",
#       "Jahr",
#       "feiern",
#       "Absprung",
#       "Verpasst",
#       "je",
#       "rav",
#       "Limit",
#       "Pause",
#       "Nonstop",
#       "drei",
#       "Tag",
#       "Wach",
#       "Substanz",
#       "brause",
#       "Acid",
#       "Techno",
#       "Electro",
#       "Sound",
#       "surfen",
#       "808",
#       "303",
#       "Synapse",
#       "twerken",
#       "droge",
#       "Bass",
#       "programmieren",
#       "rav",
#       "Verstand",
#       "verlieren",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "Ouah",
#       "Reckless",
#       "Alter",
#       "ick",
#       "drauf",
#       "drauf",
#       "ick",
#       "nie",
#       "alt",
#       "Rave",
#       "Lass",
#       "Afterhour",
#       "Susanne",
#       "Schöneberg",
#       "dikka",
#       "Ouah",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav",
#       "rav"
#     ]
#   },
#   {
#     "song_id": "a26fc63e-d1d8-4482-b82d-91e408aeb1f9",
#     "artist_name": "DJ Reckless",
#     "song_title": "Hustle Non Stop",
#     "album_name": "Trap Tape",
#     "year": "July 5, 2019",
#     "song_url": "https://genius.com/Dj-reckless-and-skinny-finsta-hustle-non-stop-lyrics",
#     "album_url": "https://genius.com/albums/Dj-reckless-and-skinny-finsta/Trap-tape",
#     "lyrics_clean": "ough skinny finsta dj reckless ough frauenarzt es geht um tapes mane ich bin kein berliner nein doch kenne alle spieler ja skinny voyou finsta ist der untergrund tape dealer aha mafia mafia tapemafia boom boom kassettenhandel schwarz wie ein puma ough businesspartner ist der frauenarzt ah ja ruf mich an und frag mich ob du kaufen darfst brrrt wir haben gute gute gute gute gute los los beweg deinn arsch aus deiner bude mane ich grinde wie ein skater wrrm get buck aus dem weg player hater boom boom auch dj reckless ist ein kingpin oh ja triff uns im süden am fachsimpeln hustle non stop hustlehustle non stop es geht um tapes mane hustle non stop huhuhustle non stop es geht um tapes mane hustle non stop hustlehustle non stop es geht um tapes mane hustle non stop huhuhustle non stop es geht um tapes mane verticke tapes so wie crack deine mutter meine ex skinny finsta und der mac deine nutte mein geschäft dj reckless regelt dinge mit dem finger an dem regler wickelt bitches um den finger wie ein sexualstraftäter skrrt statt mich zu rasieren nutze ich die zeit lieber um geld zu verdienen hussle non stop mache gold mit atzenkopp push den untergrund vom block bis mir mal der atem stoppt yeah burn wir ziehn das durch bis zum tod bis aufs blut wenn du willst wenn ich will wirst du gekillt bitches lieben dicke fette harte rapperschwänze deshalb rapp ich wie ein gangsta und geb tapes in sammlerhände yeah hustle non stop hustlehustle non stop es geht um tapes mane hustle non stop huhuhustle non stop es geht um tapes mane hustle non stop hustlehustle non stop es geht um tapes mane hustle non stop huhuhustle non stop es geht um tapes mane es geht um tapes mann ough es geht um tapes mann ough",
#     "lyrics_tokens": [
#       "skinny",
#       "finsta",
#       "dj",
#       "reckless",
#       "frauenarzt",
#       "geht",
#       "tapes",
#       "mane",
#       "berliner",
#       "nein",
#       "kenne",
#       "spieler",
#       "ja",
#       "skinny",
#       "voyou",
#       "finsta",
#       "untergrund",
#       "tape",
#       "dealer",
#       "aha",
#       "mafia",
#       "mafia",
#       "tapemafia",
#       "boom",
#       "boom",
#       "kassettenhandel",
#       "schwarz",
#       "puma",
#       "businesspartner",
#       "frauenarzt",
#       "ja",
#       "ruf",
#       "frag",
#       "kaufen",
#       "darfst",
#       "brrrt",
#       "gute",
#       "gute",
#       "gute",
#       "gute",
#       "gute",
#       "los",
#       "los",
#       "beweg",
#       "deinn",
#       "arsch",
#       "bude",
#       "mane",
#       "grinde",
#       "skater",
#       "wrrm",
#       "get",
#       "buck",
#       "player",
#       "hater",
#       "boom",
#       "boom",
#       "dj",
#       "reckless",
#       "kingpin",
#       "ja",
#       "triff",
#       "süden",
#       "fachsimpeln",
#       "hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "hustle",
#       "non",
#       "stop",
#       "huhuhustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "hustle",
#       "non",
#       "stop",
#       "huhuhustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "verticke",
#       "tapes",
#       "crack",
#       "mutter",
#       "ex",
#       "skinny",
#       "finsta",
#       "mac",
#       "nutte",
#       "geschäft",
#       "dj",
#       "reckless",
#       "regelt",
#       "dinge",
#       "finger",
#       "regler",
#       "wickelt",
#       "bitches",
#       "finger",
#       "sexualstraftäter",
#       "skrrt",
#       "statt",
#       "rasieren",
#       "nutze",
#       "zeit",
#       "lieber",
#       "geld",
#       "verdienen",
#       "hussle",
#       "non",
#       "stop",
#       "mache",
#       "gold",
#       "atzenkopp",
#       "push",
#       "untergrund",
#       "block",
#       "mal",
#       "atem",
#       "stoppt",
#       "yeah",
#       "burn",
#       "ziehn",
#       "tod",
#       "aufs",
#       "blut",
#       "willst",
#       "gekillt",
#       "bitches",
#       "lieben",
#       "dicke",
#       "fette",
#       "harte",
#       "rapperschwänze",
#       "deshalb",
#       "rapp",
#       "gangsta",
#       "geb",
#       "tapes",
#       "sammlerhände",
#       "yeah",
#       "hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "hustle",
#       "non",
#       "stop",
#       "huhuhustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "hustle",
#       "non",
#       "stop",
#       "huhuhustle",
#       "non",
#       "stop",
#       "geht",
#       "tapes",
#       "mane",
#       "geht",
#       "tapes",
#       "mann",
#       "geht",
#       "tapes",
#       "mann"
#     ],
#     "lyrics_lemmas": [
#       "Skinny",
#       "Finsta",
#       "dj",
#       "Reckless",
#       "Frauenarzt",
#       "gehen",
#       "Tapes",
#       "man",
#       "Berliner",
#       "Nein",
#       "kennen",
#       "Spieler",
#       "ja",
#       "Skinny",
#       "voyou",
#       "Finsta",
#       "Untergrund",
#       "Tape",
#       "dealer",
#       "aha",
#       "Mafia",
#       "mafia",
#       "Tapemafia",
#       "Boom",
#       "Boom",
#       "Kassettenhandel",
#       "schwarz",
#       "Puma",
#       "Businesspartner",
#       "frauenarzen",
#       "ja",
#       "Ruf",
#       "Frag",
#       "kaufen",
#       "darfst",
#       "brrren",
#       "gut",
#       "gut",
#       "gut",
#       "gut",
#       "gut",
#       "Los",
#       "los",
#       "Beweg",
#       "Deinn",
#       "arsch",
#       "bude",
#       "Mane",
#       "Grinde",
#       "skat",
#       "Wrrm",
#       "Get",
#       "Buck",
#       "Player",
#       "Hater",
#       "Boom",
#       "Boom",
#       "dj",
#       "Reckless",
#       "Kingpin",
#       "ja",
#       "Triff",
#       "Süden",
#       "fachsimpeln",
#       "Hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tapes",
#       "Mane",
#       "Hustle",
#       "non",
#       "Stop",
#       "huhuhustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tapes",
#       "Mane",
#       "Hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tapes",
#       "Mane",
#       "Hustle",
#       "non",
#       "Stop",
#       "huhuhustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tapes",
#       "Mane",
#       "Verticke",
#       "Tapes",
#       "Crack",
#       "Mutter",
#       "ex",
#       "Skinny",
#       "Finsta",
#       "Mac",
#       "Nutte",
#       "Geschäft",
#       "dj",
#       "Reckless",
#       "regeln",
#       "ding",
#       "fing",
#       "regl",
#       "wickeln",
#       "Bitch",
#       "Finger",
#       "Sexualstraftäter",
#       "skrren",
#       "statt",
#       "rasieren",
#       "nutz",
#       "Zeit",
#       "lieb",
#       "Geld",
#       "verdienen",
#       "Hussle",
#       "non",
#       "Stop",
#       "machen",
#       "Gold",
#       "atzenkopp",
#       "Push",
#       "Untergrund",
#       "Block",
#       "mal",
#       "Atem",
#       "stoppen",
#       "Yeah",
#       "burn",
#       "ziehn",
#       "Tod",
#       "auf",
#       "Blut",
#       "willst",
#       "gekillt",
#       "Bitch",
#       "Lieben",
#       "dick",
#       "Fette",
#       "hart",
#       "Rapperschwänze",
#       "deshalb",
#       "rapp",
#       "Gangsta",
#       "Geb",
#       "Tape",
#       "Sammlerhände",
#       "Yeah",
#       "Hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tapes",
#       "Mane",
#       "Hustle",
#       "non",
#       "Stop",
#       "huhuhustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tapes",
#       "Mane",
#       "Hustle",
#       "non",
#       "stop",
#       "hustlehustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tapes",
#       "Mane",
#       "Hustle",
#       "non",
#       "Stop",
#       "huhuhustle",
#       "non",
#       "Stop",
#       "gehen",
#       "Tape",
#       "Mane",
#       "gehen",
#       "Tape",
#       "Mann",
#       "gehen",
#       "Tape",
#       "Mann"
#     ]
#   }
# ]

# %%
# Speicherpfad
output_path = os.path.join(folder_path, "processed_songs.json")

# %%
# Alle Songs speichern
df_songs.to_json(output_path, orient="records", force_ascii=False, indent=2)

print(f"JSON gespeichert unter: {output_path}")
# Out:
# JSON gespeichert unter: ../data/processed\processed_songs.json
